# %%
import pandas as pd
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data/bmd.csv')

# %%
df.head()
# Out:
#       id        age sex     fracture  weight_kg  height_cm      medication  \
# 0    469  57.052768   F  no fracture       64.0      155.5  Anticonvulsant
# 1   8724  75.741225   F  no fracture       78.0      162.0   No medication
# 2   6736  70.778900   M  no fracture       73.0      170.5   No medication
# 3  24180  78.247175   F  no fracture       60.0      148.0   No medication
# 4  17072  54.191877   M  no fracture       55.0      161.0   No medication
#
#    waiting_time     bmd
# 0            18  0.8793
# 1            56  0.7946
# 2            10  0.9067
# 3            14  0.7112
# 4            20  0.7909

# %% [markdown]
# - id – patient’s number
# - age – patient’s age
# - fracture – hip fracture (fracture / no fracture)
# - weight_kg – weight measured in Kg
# - height_cm – height measure in cm
# - waiting_time – time the patient had to wait for the densitometry (in minutes)
# - bmd – bone mineral density measure in the hip

# %%
X = df[['age' , 'sex' , 'fracture' , 'weight_kg' , 'height_cm' , 'medication' , 'waiting_time']]
y = df[['bmd']]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (135, 7) (135, 1)
# Test set: (34, 7) (34, 1)

# %%
X_train
# Out:
#            age sex     fracture  weight_kg  height_cm       medication  \
# 141  74.796883   F     fracture       48.0      160.0    No medication
# 105  68.571308   F  no fracture       48.0      161.0    No medication
# 11   73.970471   F  no fracture       68.0      164.0    No medication
# 28   70.421873   F  no fracture       55.0      162.0   Anticonvulsant
# 134  54.152735   M     fracture       79.0      161.0    No medication
# ..         ...  ..          ...        ...        ...              ...
# 50   43.450712   M  no fracture       75.0      165.0  Glucocorticoids
# 87   65.134357   M  no fracture       67.0      157.0    No medication
# 104  49.209663   M  no fracture       66.0      157.0    No medication
# 129  76.944737   F     fracture       37.0      152.0    No medication
# 122  69.213935   F     fracture       56.0      157.0    No medication
#
#      waiting_time
# 141            96
# 105             6
# 11              5
# 28             15
# 134            38
# ..            ...
# 50             16
# 87              5
# 104            47
# 129             7
# 122            15
#
# [135 rows x 7 columns]
