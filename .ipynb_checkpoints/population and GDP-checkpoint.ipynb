# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import math

from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
pop = pd.read_csv('GDP and population/china_population.txt')
GDP = pd.read_csv('GDP and population/china_gdp.csv')

# %%
pop = pop[['Year','Value']]
pop=pop.rename(columns={'Value':'Population'})

# %%
GDP=GDP.rename(columns={'Value':'GDP'})

# %%
pop_gdp = pd.merge(GDP,pop)

# %%
pop_gdp.head()
# Out:
#    Year           GDP  Population
# 0  1960  5.918412e+10   667070000
# 1  1961  4.955705e+10   660330000
# 2  1962  4.668518e+10   665770000
# 3  1963  5.009730e+10   682335000
# 4  1964  5.906225e+10   698355000

# %%
plt.figure(figsize=(10,7))
plt.scatter(pop_gdp.Year,pop_gdp.GDP)
plt.grid()
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(pop_gdp.Year ,pop_gdp.Population)
plt.grid()
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(pop_gdp.GDP,pop_gdp.Population )
plt.grid()
plt.ylabel('GDP')
plt.xlabel('Population')
plt.show()

# %%
pop_gdp.corr()
# Out:
#                 Year       GDP  Population
# Year        1.000000  0.723858    0.990633
# GDP         0.723858  1.000000    0.634859
# Population  0.990633  0.634859    1.000000

# %%
msk = np.random.rand(len(pop_gdp)) < 0.8
train = pop_gdp[msk]
test = pop_gdp[~msk]

# %%
Pop_y = np.asanyarray(train[['Population']])
GDP_X = np.asanyarray(train[['GDP']])

# %%
y_n =[]
for i in Pop_y :
    temp = ((i -  np.average(Pop_y))/(Pop_y.max() - Pop_y.min() ) )
    y_n = np.append(y_n,temp)

# %%
X_n =[]
for i in GDP_X :
    temp = ((i -  np.average(GDP_X))/(GDP_X.max() - GDP_X.min() ) )
    X_n = np.append(X_n,temp)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_n.reshape(45,-1),y_n.reshape(45,-1)) # we have a problem here , 45 has been changeing , 45should be dynamic

print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[0.87050151]]
# Intercept:  [6.38267254e-17]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_n, y_n,  color='blue')
plt.plot(X_n, regr.coef_[0][0]*X_n + regr.intercept_[0], '-r')
plt.xlabel("GDP")
plt.ylabel("population")
plt.grid()
plt.show()

# %%
Pop_y_t = np.asanyarray(test[['Population']])
GDP_X_t = np.asanyarray(test[['GDP']])

# %%
y_n_t =[]
for i in Pop_y_t :
    temp = ((i -  np.average(Pop_y_t))/(Pop_y_t.max() - Pop_y_t.min() ) )
    y_n_t = np.append(y_n_t,temp)

# %%
X_n_t =[]
for i in GDP_X_t :
    temp = ((i -  np.average(GDP_X_t))/(GDP_X_t.max() - GDP_X_t.min() ) )
    X_n_t = np.append(X_n_t,temp)

# %%
test_y_ = regr.predict(X_n_t.reshape(10,-1)) # we have a problem here , 10 has been changeing 

print("R2-score: %.2f" % r2_score(y_n_t , test_y_) )
# Out:
# R2-score: 0.28

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X_n.reshape(45,-1)) # we have a problem here , 45 has been changeing

# %%
X_poly
# Out:
# array([[ 1.00000000e+00, -1.34179532e-01,  1.80041467e-02],
#        [ 1.00000000e+00, -1.34458134e-01,  1.80789897e-02],
#        [ 1.00000000e+00, -1.34127121e-01,  1.79900846e-02],
#        [ 1.00000000e+00, -1.33257425e-01,  1.77575414e-02],
#        [ 1.00000000e+00, -1.32224563e-01,  1.74833350e-02],
#        [ 1.00000000e+00, -1.31996794e-01,  1.74231536e-02],
#        [ 1.00000000e+00, -1.32196978e-01,  1.74760411e-02],
#        [ 1.00000000e+00, -1.31350529e-01,  1.72529615e-02],
#        [ 1.00000000e+00, -1.30110016e-01,  1.69286163e-02],
#        [ 1.00000000e+00, -1.29425527e-01,  1.67509671e-02],
#        [ 1.00000000e+00, -1.28106397e-01,  1.64112489e-02],
#        [ 1.00000000e+00, -1.25718958e-01,  1.58052565e-02],
#        [ 1.00000000e+00, -1.24277593e-01,  1.54449200e-02],
#        [ 1.00000000e+00, -1.22267403e-01,  1.49493179e-02],
#        [ 1.00000000e+00, -1.24592448e-01,  1.55232781e-02],
#        [ 1.00000000e+00, -1.21830127e-01,  1.48425798e-02],
#        [ 1.00000000e+00, -1.20589024e-01,  1.45417127e-02],
#        [ 1.00000000e+00, -1.20131225e-01,  1.44315113e-02],
#        [ 1.00000000e+00, -1.19240611e-01,  1.42183234e-02],
#        [ 1.00000000e+00, -1.16776485e-01,  1.36367475e-02],
#        [ 1.00000000e+00, -1.13950376e-01,  1.29846882e-02],
#        [ 1.00000000e+00, -1.09158299e-01,  1.19155342e-02],
#        [ 1.00000000e+00, -1.09999749e-01,  1.20999448e-02],
#        [ 1.00000000e+00, -1.08843729e-01,  1.18469574e-02],
#        [ 1.00000000e+00, -1.05425533e-01,  1.11145429e-02],
#        [ 1.00000000e+00, -1.04162867e-01,  1.08499028e-02],
#        [ 1.00000000e+00, -1.01981924e-01,  1.04003129e-02],
#        [ 1.00000000e+00, -9.77639631e-02,  9.55779248e-03],
#        [ 1.00000000e+00, -9.60235406e-02,  9.22052035e-03],
#        [ 1.00000000e+00, -8.44417753e-02,  7.13041342e-03],
#        [ 1.00000000e+00, -5.54760474e-02,  3.07759184e-03],
#        [ 1.00000000e+00, -3.32991207e-02,  1.10883144e-03],
#        [ 1.00000000e+00, -2.20639710e-02,  4.86818817e-04],
#        [ 1.00000000e+00, -9.74613668e-03,  9.49871802e-05],
#        [ 1.00000000e+00,  2.83340585e-03,  8.02818872e-06],
#        [ 1.00000000e+00,  4.93829104e-02,  2.43867184e-03],
#        [ 1.00000000e+00,  8.10911617e-02,  6.57577651e-03],
#        [ 1.00000000e+00,  1.25831031e-01,  1.58334483e-02],
#        [ 1.00000000e+00,  2.02790577e-01,  4.11240182e-02],
#        [ 1.00000000e+00,  3.03229269e-01,  9.19479899e-02],
#        [ 1.00000000e+00,  3.51830506e-01,  1.23784705e-01],
#        [ 1.00000000e+00,  4.46924106e-01,  1.99741157e-01],
#        [ 1.00000000e+00,  5.87858617e-01,  3.45577753e-01],
#        [ 1.00000000e+00,  6.81880472e-01,  4.64960978e-01],
#        [ 1.00000000e+00,  8.65541866e-01,  7.49162722e-01]])

# %%
regrp = linear_model.LinearRegression()
y_train_ = regrp.fit(X_poly, y_n.reshape(45,-1)) # we have a problem here , 45 has been changeing 

print ('Coefficients: ', regrp.coef_)
print ('Intercept: ',regrp.intercept_)
# Out:
# Coefficients:  [[ 0.          2.06200311 -2.2934545 ]]
# Intercept:  [0.12629263]

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_n, y_n,  color='blue')
XX = np.arange(-0.5 , 1.5 , 0.1)
yy = regrp.intercept_[0]+ regrp.coef_[0][1]*XX+ regrp.coef_[0][2]*np.power(XX, 2)
plt.plot(XX, yy, '-r' )
plt.grid()
plt.xlabel("GDP")
plt.ylabel("population")
plt.show()

# %%
X_poly_test = poly.fit_transform(X_n_t.reshape(10,-1)) # we have a problem here , 10 has been changeing 
test_y_p = regrp.predict(X_poly_test)

# %%
print("R2-score: %.2f" % r2_score(y_n_t,test_y_p ) )
# Out:
# R2-score: 0.59

# %%
def sigmoid(x, beta_1 , beta_2 , beta_3):
    y =(-(beta_1*np.exp(-(beta_2)*x))+ beta_3)
    return y

# %%
beta_1 =0.0000001
beta_2 =128
beta_3 =0.4
#logistic function
Y_pred = sigmoid(X_n,beta_1,beta_2,beta_3)

#plot initial prediction against datapoints
plt.plot(X_n, Y_pred)
plt.grid()

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, X_n,y_n)
#print the final parameters
print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1] , popt[2]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5080/627976586.py in <module>
#       2 popt, pcov = curve_fit(sigmoid, X_n,y_n)
#       3 #print the final parameters
# ----> 4 print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1] , popt[2]))
#
# TypeError: not all arguments converted during string formatting

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_n, y_n,  color='blue')
plt.plot(X_n , sigmoid(X_n ,popt[0],popt[1]) , color='red')
plt.grid()
plt.xlabel("GDP")
plt.ylabel("population")
plt.show()
